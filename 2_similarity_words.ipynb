# %%
# !pip install -q sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# ...

# %%
words = ["doctor", "hospital", "teacher", "school", "banana"]

embeddings = model.encode(words)

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(embeddings)

for i in range(len(words)):
    for j in range(len(words)):
        print(f"{words[i]:<10} vs {words[j]:<10} : {similarity_matrix[i][j]:.2f}")
    print()
# Out:
# doctor     vs doctor     : 1.00
# doctor     vs hospital   : 0.60
# doctor     vs teacher    : 0.48
# doctor     vs school     : 0.40
# doctor     vs banana     : 0.34
#
# hospital   vs doctor     : 0.60
# hospital   vs hospital   : 1.00
# hospital   vs teacher    : 0.27
# hospital   vs school     : 0.40
# hospital   vs banana     : 0.22
#
# teacher    vs doctor     : 0.48
# teacher    vs hospital   : 0.27
# teacher    vs teacher    : 1.00
# teacher    vs school     : 0.62
# teacher    vs banana     : 0.30
#
# school     vs doctor     : 0.40
# school     vs hospital   : 0.40
# school     vs teacher    : 0.62
# school     vs school     : 1.00
# school     vs banana     : 0.36
#
# banana     vs doctor     : 0.34
# banana     vs hospital   : 0.22
# banana     vs teacher    : 0.30
# banana     vs school     : 0.36
# banana     vs banana     : 1.00

# %% [markdown]
# ### Activity ###

# %%
sentences = [
    "I love teaching students",
    "I enjoy guiding learners",
    "The weather is very hot today"
]

# %%
embeddings = model.encode(sentences)

# %%
for i in range(len(sentences)):
    for j in range(len(sentences)):
        print(f"\"{sentences[i]}\"")
        print(f"   vs \"{sentences[j]}\"  →  Similarity: {similarity_matrix[i][j]:.2f}")
    print("\n")
# Out:
# "I love teaching students"
#    vs "I love teaching students"  →  Similarity: 1.00
# "I love teaching students"
#    vs "I enjoy guiding learners"  →  Similarity: 0.59
# "I love teaching students"
#    vs "The weather is very hot today"  →  Similarity: -0.02
#
#
# "I enjoy guiding learners"
#    vs "I love teaching students"  →  Similarity: 0.59
# "I enjoy guiding learners"
#    vs "I enjoy guiding learners"  →  Similarity: 1.00
# "I enjoy guiding learners"
#    vs "The weather is very hot today"  →  Similarity: -0.02
#
#
# "The weather is very hot today"
#    vs "I love teaching students"  →  Similarity: -0.02
# "The weather is very hot today"
#    vs "I enjoy guiding learners"  →  Similarity: -0.02
# "The weather is very hot today"
#    vs "The weather is very hot today"  →  Similarity: 1.00
